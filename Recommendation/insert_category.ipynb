# %%
import pandas as pd

# %%
df = pd.read_csv('job_dataset.csv')

# %%
df['Category'].unique()
# Out:
# array(['Banking & Finance', 'Real Estate', 'Civil Services',
#        'Information Technology', 'Recruiting Services', 'Others',
#        'Manufacturing', 'Entertainment', 'Education', 'Food & Beverages',
#        'Engineering', 'Insurance',
#        'Electronics/Electrical/Mechanical Equipment', 'Telecommunication',
#        'Chemical/Plastic/Paper/Petrochemical', 'Exec. / Management, HR',
#        'Exec. / Management, Sales / Marketing, Business Administration',
#        'Educate/Train/Teaching',
#        'Business Administration, Exec. / Management, Economics',
#        'Educate/Train/Teaching, Exec. / Management', 'Consultancy',
#        'Exec. / Management, Educate/Train/Teaching',
#        'Assistant, Educate/Train/Teaching, Exec. / Management',
#        'Exec. / Management, Educate/Train/Teaching, Business Administration',
#        'Educate/Train/Teaching, Exec. / Management, Sales / Marketing',
#        'Exec. / Management, Operations Management, Business Administration',
# ...
